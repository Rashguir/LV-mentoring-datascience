# %% [markdown]
# # In Vino Veritas

# %% [markdown]
# ## Data Loading

# %%
# %pylab inline
import pandas as pd
import seaborn
import numpy
from pylab import rcParams
rcParams['figure.figsize'] = 16, 4

dataSet = pd.read_csv("./data/winequality-white.csv", sep=";")
dataSet.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# ...

# %%
dataSet.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
gbQuality = dataSet.groupby("quality")['chlorides'].mean()
gbQuality = gbQuality.sort_values()
plt.title("Mean chlorides by quality")
g = seaborn.barplot(gbQuality.index.values, gbQuality.values)
_=g.set_xticklabels(gbQuality.index.values, rotation=30)
plt.show()

# %% [markdown]
# graph is not ordered but we can see some kind of correlation between chlorides and quality

# %%
plt.title("chlorides by alcohol")
subsample = dataSet.sample(n=100)
#seaborn.regplot(subsample['quality'], subsample['density'])
#seaborn.regplot(subsample['quality'], subsample['alcohol'])
#seaborn.regplot(subsample['free sulfur dioxide'], subsample['total sulfur dioxide'])
#seaborn.regplot(subsample['alcohol'], subsample['density'])
#seaborn.regplot(subsample['residual sugar'], subsample['density'])
seaborn.regplot(subsample['residual sugar'], subsample['alcohol'])

# %% [markdown]
# There is a relation between:
#
# - alcohol and quality
# - free sulfur dioxide and total sulfur dioxide
# - density and alcohol
# - residual sugar and alcohol
# - residual sugar and density
# - quality and density
